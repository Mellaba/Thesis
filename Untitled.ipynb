# %%
import networkx as nx
import matplotlib.pyplot as plt
import random 
# %matplotlib inline 
import itertools
import collections

def undercon(G, k):
    to_be_removed = []
    for n in G:
        if len(G[n]) < k:
            to_be_removed.append(n)

    for node in to_be_removed:       
        G.remove_node(node) # G.remove_node(n)
    
    return G

def subsumed(G, k):
    to_be_removed = []
    for n in G:
        n_list = [] 
        for i in G[n]:
            n_list.append(i)

        for m in G:
            m_list = []
            if m != n:
                for j in G[m]:
                    m_list.append(j)

                if set(m_list).issubset(set(n_list)) and len(m_list) > k:
                    if m not in to_be_removed:
                        to_be_removed.append(m)

    for node in to_be_removed:
        G.remove_node(node)
    
    return G
    

def create_edge(G, K, node_1, node_2):
    # node 1 is niet node 2
    # create edge
    # if not check clique
        # remove edge
    # ...
    
def clique_check(G, K, node_1, node_2):
    for clique in nx.cliques_containing_node(G, nodes=node_1):
        for node in clique:
            if node == i and len(clique) > K-1:
                flag = 1
                break
    if flag == 1:
        continue

def gen_random_graph(N, K):
    G = nx.Graph()
    G.add_nodes_from(range(N))
    
    Somenodes = random.randrange(N)
    flag = 0
    
    p = 0.1
    for node_1 in G: # Voor een node in de graph
        flag = 0
        for node_2 in G:
            flag = 0
            if random.random() < p and node_1 != node_2:
                
                
            ran = random.random()
            
#         for j in nx.cliques_containing_node(G, nodes=i): # voor een clique waar node i in zit
#             if len(j) > K-1: # Als de clique al max is dan
#                 flag = 1
#                 break
#         if flag == 1:
#             continue
#         rnum = random.randrange(10*K)
#         for count in range(rnum):
#             flag = 0
#             randomnode = random.randrange(N)
#             if randomnode!= i:
#                 for clique in nx.cliques_containing_node(G, nodes=randomnode):
#                     for node in clique:
#                         if node == i and len(clique) > K-1:
#                             flag = 1
#                             break
#                 if flag == 1:
#                     continue
                
#                 ran = random.random()
#                 if ran > 0.5:
#                     G.add_edge(i,randomnode)
    return G

def cliques_of_size(G, n):
    cliques = []
    for clique in nx.find_cliques(G):
        if len(clique) == n:
            cliques.append(set(clique))
    return cliques

def get_mergable_nodes(cliques, k):
    mergable_nodes = set()

    for clique_a, clique_b in itertools.combinations(cliques, 2):
        if len(clique_a & clique_b) == k - 1:
            mergable_nodes.add(tuple(clique_a ^ clique_b))
    
    return mergable_nodes

def symmetry(G, k):
    cliques = cliques_of_size(G, k)
    mergable_nodes = get_mergable_nodes(cliques, k)

    mergable_nodes = list(map(list, mergable_nodes))
    while mergable_nodes:
        node_a, node_b = mergable_nodes.pop()
        G = nx.contracted_nodes(G, node_a, node_b)

        for i in range(len(mergable_nodes)):
            if mergable_nodes[i][0] == node_b:
                mergable_nodes[i][0] = node_a
            if mergable_nodes[i][1] == node_b:
                mergable_nodes[i][1] = node_a
                
    return G

# %%
# for j in range(30):
K = 4
G = gen_random_graph(100, K)

nx.draw(G,with_labels = True)
print(nx.number_of_nodes(G))
plt.show()

G = subsumed(G, K)
nx.draw(G,with_labels = True)
print(nx.number_of_nodes(G))
plt.show()

G = symmetry(G, K)
nx.draw(G,with_labels = True)
print(nx.number_of_nodes(G))
plt.show()

G = undercon(G, K)
nx.draw(G,with_labels = True)
print(nx.number_of_nodes(G))
plt.show()

tempdic = nx.node_clique_number(G)
maxnu = 0
for a in tempdic:
    if tempdic[a] > maxnu: 
        maxnu = tempdic[a]

print(maxnu)
# Out:
# 100
# 100
# 1
# 0
# 0

# %%
K = 4
G = gen_random_graph(100, K)

nx.draw(G,with_labels = True)
print(nx.number_of_nodes(G))
plt.show()

G = subsumed(G, K)
nx.draw(G,with_labels = True)
print(nx.number_of_nodes(G))
plt.show()

G = symmetry(G, K)
nx.draw(G,with_labels = True)
print(nx.number_of_nodes(G))
plt.show()

G = undercon(G, K)
nx.draw(G,with_labels = True)
print(nx.number_of_nodes(G))
plt.show()

tempdic = nx.node_clique_number(G)
maxnu = 0
for a in tempdic:
    if tempdic[a] > maxnu: 
        maxnu = tempdic[a]

print(maxnu)
# Out:
# 100
# 100
# 2
# 0
# 0

# %%
K = 4
G = gen_random_graph(300, K)

nx.draw(G,with_labels = True)
print(nx.number_of_nodes(G))
plt.show()

G = subsumed(G, K)
nx.draw(G,with_labels = True)
print(nx.number_of_nodes(G))
plt.show()

G = symmetry(G, K)
nx.draw(G,with_labels = True)
print(nx.number_of_nodes(G))
plt.show()

G = undercon(G, K)
nx.draw(G,with_labels = True)
print(nx.number_of_nodes(G))
plt.show()

tempdic = nx.node_clique_number(G)
maxnu = 0
for a in tempdic:
    if tempdic[a] > maxnu: 
        maxnu = tempdic[a]

print(maxnu)
# Out:
# 300
# 300
# 293
# 292
# 4
