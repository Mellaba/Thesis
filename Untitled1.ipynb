# %%
import networkx as nx
import matplotlib.pyplot as plt
import random 
# %matplotlib inline 
import itertools
import collections
from reduction_steps_graph_gen import *

# %%
#for i in range(1, 10):
G = gen_random_graph(300, 4, 10)
nx.draw(G,with_labels = True)
print("Nodes", nx.number_of_nodes(G))
if len(G) != 0:
    print(average_degree(G))
plt.show()

# aantal nodes average connectivity
# Out:
# Nodes 298
# 20.20805369127517
